# %% [markdown]
# Click [here](http://www.espn.com/nhl/player/_/id/1569/rick-nash), and [here](http://www.espn.com/nhl/player/_/id/3081/henrik-lundqvist).  What you see are two websites that describe two different players, but are actually pretty similar.
#
# >Remember, you can view the HTML of a webpage by pressing command+shift+c or control+shift+c on a pc.  Or by going to the Chrome menu at the top, followed by  View -> Developer -> Developer Tools.
#
# Let's take a look.

# %% [markdown]
# <img src="http://jkatzy.com/wp-content/uploads/2017/10/henrik-729x353.png" width="60%"/>
# <img src="http://jkatzy.com/wp-content/uploads/2017/10/henrik-html.png" width="60%"/>

# %% [markdown]
# <img src="http://jkatzy.com/wp-content/uploads/2017/10/rick-nash-705x400.png" width="60%" />
# <img src="http://jkatzy.com/wp-content/uploads/2017/10/rick-html.png" width="60%">
#
# **Where do you think** the information comes from to display Henrik's information vs Rick Nash's?  How does a user ask for information about a specific player?

# %% [markdown]
# ## Generating different code
#
# Ok, so essentially the browser sends a different input.  And from that you generate a different output.
#
# This is a job for functions.  Let's start with the following function.

# %%
def printSiteWithPlayerName(playerName):
  return "<h1> " + playerName "</h1>"

def printSiteWithoutName()

# %% [markdown]
# ### Do you know it?
#
# Ok, so this section covered a couple of components of python.  Take a guess at the following:
#
# What word can you use to gather information from the user?
# How do you store information from the user?
# How can you respond with information to the user?
