# %% [markdown]
# # Discussion questions
#
# Last class, we saw HTML.  Let's see how much of it we remember.

# %% [markdown]
# <h1>Welcome to HTML </h1>

# %%
# Out:
# 2

# %% [markdown]
# ## Playing with the web inspector
#
# The first thing we saw was how to use the web inspector that comes with an Internet browser (like Google Chrome).  Here is what you need to do.
#
#
# 1. Go to [Google](https://www.google.com) and open up the web inspector.
# 2. Now choose an element, like the word "About" in the top left hand corner.  What type of HTML element is the word "About"?
# 3. Try to use the web inspector to change the word "About" to "Don't click here!".

# %% [markdown]
# ![alt text](https://previews.dropbox.com/p/thumb/AASk6N9xnT47WcjhE3NY9kO72GT3z3DODn0QBxfmE2GvxUWk1YhDeTbOkNWQXmHwnZEVqoxwcFFhPEj9uc7hRe79KpIvmfDVe5qHTfp3Z8CUDe9-5DATlYQ5_easrGhMvWqJKRtRjFWUwp1lXmjQlyaVpAw-keprexeAopmtcQH0Be52GOF2mYl1FW_DTG8FRaScsAbdt_pOssFeASYyOScExfxEHXO-_30gwsCN9IUUyWtcZPoCy3oaBImAGj9XoeU/p.png?size=1024x768&size_mode=3)

# %% [markdown]
# ## Writing our own HTML

# %% [markdown]
# The next thing we learned was how to write our own HTML.
#
# 1. Get started by writing a header that says, "Welcome Back!"
#     > **Remember:** To edit the code below, first click "Remix to Edit".  Then, click on the "Both" button at the bottom of the editor to view the output.
#
# 2. Next write a paragraph that says "Soon, we'll learn the following:"
#
# 3. Now for working with lists.  Below the paragraph tag, create a list with three bullet points that says:
#   * how to create links in html
#   * how to select elements with css
#   * how to change element attributes with css

# %%
#@title

import IPython

iframe = """<!-- Copy and Paste Me -->
<div class="glitch-embed-wrap" style="height: 420px; width: 100%;">
  <iframe
    allow="geolocation; microphone; camera; midi; encrypted-media"
    src="https://glitch.com/embed/#!/embed/silly-lightning?path=index.html&previewSize=33"
    alt="silly-lightning on Glitch"
    style="height: 100%; width: 100%; border: 0;">
  </iframe>
</div>"""

IPython.display.HTML(iframe)
# Out:
# <!-- Copy and Paste Me -->
# <div class="glitch-embed-wrap" style="height: 420px; width: 100%;">
#   <iframe
#     allow="geolocation; microphone; camera; midi; encrypted-media"
#     src="https://glitch.com/embed/#!/embed/silly-lightning?path=index.html&previewSize=33"
#     alt="silly-lightning on Glitch"
#     style="height: 100%; width: 100%; border: 0;">
#   </iframe>
# </div>

# %% [markdown]
# When done, your HTML will display the following:

# %% [markdown]
# ![](https://previews.dropbox.com/p/thumb/AAQZ76dRgMXgsgegH9rW0YVA9aLHkp4PNMe8eefopVrT1w4FTjBrvjc1BJ8LqnPrthMoiayTSWnAh7RG5HUkGQ3YvZ5qMlELiGY5_QgzNKuFtepPpdA2eUEHaD1OLA0wCLum0kvUN79aqsKvvNYEUu8HmTMazNxZ5sn1ehxT0wkCF5fpjkJbHqBZOgCCg97e0W7zax6IdDzJZNlEJqXSHgMWueQPDt2VZotJOb9kICl875-1OwoLe-fLhmGwnjARs1U/p.png?size=2048x1536&size_mode=3)

# %% [markdown]
# ## Bonus questions
#
# 1. Why do lists require two types of tags (both `ul` and `li`).  What does the `ul` indicate and what does the `li` indicate?
# 2. When should you use an ordered list instead of an unordered list?
# 3. A lot of coding is learning how to Google your question and read documentation.  Try figuring out how to create a link in HTML.  Can you create a link in HTML that takes you to Google?

# %%
#@title

import IPython

iframe = """<!-- Copy and Paste Me -->
<div class="glitch-embed-wrap" style="height: 420px; width: 100%;">
  <iframe
    allow="geolocation; microphone; camera; midi; encrypted-media"
    src="https://glitch.com/embed/#!/embed/silly-lightning?path=index.html&previewSize=33"
    alt="silly-lightning on Glitch"
    style="height: 100%; width: 100%; border: 0;">
  </iframe>
</div>"""

IPython.display.HTML(iframe)
# Out:
# <!-- Copy and Paste Me -->
# <div class="glitch-embed-wrap" style="height: 420px; width: 100%;">
#   <iframe
#     allow="geolocation; microphone; camera; midi; encrypted-media"
#     src="https://glitch.com/embed/#!/embed/silly-lightning?path=index.html&previewSize=33"
#     alt="silly-lightning on Glitch"
#     style="height: 100%; width: 100%; border: 0;">
#   </iframe>
# </div>
