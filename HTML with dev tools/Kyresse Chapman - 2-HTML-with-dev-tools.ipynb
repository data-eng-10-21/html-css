# %% [markdown]
# # HTML with dev tools
#
# ## Objectives
#
# * Explore HTML by digging into ESPN's website.
#
#
#
# ---

# %%
<h1>hello fam</h1>
# Out:
#   File "<ipython-input-1-b934e4e9f2ee>", line 1
#     <h1>hello fam</h1>
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Time to explore
#
# <html>
#
#   <button href="www.espn.com"> Press here </button>
#
#      </html>
#
# <p> There it is. The page that we want to explore.</p>

# %% [markdown]
# <img src="http://jkatzy.com/wp-content/uploads/2017/10/NY-Rangers-300x174.png" width="400px">

# %% [markdown]
# > I hope you're viewing ESPN with the Google Chrome browser.  (You are if you see the word Chrome in the menu on the top lefthand corner of your screen.)  If not, you can download chrome [here](https://www.google.com/chrome/).

# %% [markdown]
# ## Our first inspection
#
# ### 1. Opening the inspector
#
# #### a. If you are using Chrome
#
# From the ESPN webpage, look at the menu at the chrome menu at the top of the page, and click on **view**, then at the very bottom of the view dropdown it says **developer**.
#
# Click on developer, and at the bottom of you will see **Developer Tools**. Click on **Developer Tools**. This will pop up the Google Developer Console.
#
# (A quicker way to open up the console in the future is to press command+shift+i).

# %% [markdown]
# <img src="http://raw.githubusercontent.com/JeffKatzy/html-intro/master/open-console.gif" />

# %% [markdown]
# #### b. If you are using Mozilla Firefox
# From the ESPN webpage, look at the menu at the top, and then go to Tools -> Web Developer -> Toggle Tools.
#
# This will pop up the Mozilla developer tools.
#
# (A quicker way to open up the console in the future is to press command+option+i on a Mac or command+option+c on Windows).
#
# <img src="http://jkatzy.com/wp-content/uploads/2017/10/mozilla-tools-300x228.png" />

# %% [markdown]
# #### c. If you are using Internet Explorer
#
# You can either press F12, or go to Tools -> Developer Tools.  After doing so you should see the HTML console pop up on the bottom of the screen.

# %% [markdown]
# ## 2. Highlight with the inspector
#
# Make sure that the icon at the top left of the developer tools is highlighted, as you to the right.  (If you are using Internet Explorer, the icon is in the same spot, but is a white arrow.)
#
# <img src="http://jkatzy.com/wp-content/uploads/2017/10/icon-highlighted-arrow.png" />

# %% [markdown]
# ## 3. Explore the elements
#
#
# Now, move your cursor over different parts of the page. Notice what happens to the chrome inspector.
#
# <img src="http://github.com/JeffKatzy/html-intro/blob/master/highlight-html.gif?raw=true" />

# %% [markdown]
# ## 4. Explore it from the other side
#
#
# Now what happens if, with the top left icon still highlighted, you click on an image or text in the webpage of interest to you.  How does the highlighted information relate to the content you clicked on?
#
# <img src="http://jkatzy.com/wp-content/uploads/2017/10/dom-clicked-on.png" />

# %% [markdown]
# ### 5. Finally, make some changes
#
# Now, click on and highlight the related HTML below. And press delete.
#
# * What happened to the ESPN webpage?
# * Can you highlight other HTML and manipulate the webpage through the HTML in other ways?

# %% [markdown]
# ### Change your mind...
#
# Let's ask ourselves the same questions again:
#
# * So what is HTML?
# * How does the image on the right line up to your understanding of what HTML is?
#
# <img src="http://jkatzy.com/wp-content/uploads/2017/10/wiki-HTML-image.png" />
